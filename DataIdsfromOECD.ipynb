# %%
import requests
import xmltodict
import pandas as pd
import logging
import datetime

# http://stats.oecd.org/restsdmx/sdmx.ashx/GetDataStructure/ALL
# Extract OECD KeyFamily id (dataset id) and English description

# where to save
logfile = '/Users/onurbaser/Documents/FinTech/FT_Project_1/oecd_keyfamilies.log'
datafile = '/Users/onurbaser/Documents/FinTech/FT_Project_1/OECD_key_names.csv'

# logging
logging.basicConfig(filename=logfile, filemode='w', level=logging.DEBUG)
logging.debug("Log started at %s", str(datetime.datetime.now()))

# get the data structure schema with the key families (dataset ids)
dataStructureUrl = 'http://stats.oecd.org/RESTSDMX/sdmx.ashx/GetDataStructure/ALL/'

try:
    r = requests.get(dataStructureUrl, timeout=61)
except requests.exceptions.ReadTimeout:
    print("Data request read timed out")
    logging.debug('Data read timed out')
except requests.exceptions.Timeout:
    print("Data request timed out")
    logging.debug('Data request timed out')
except requests.exceptions.HTTPError:
    print("HTTP error")
    logging.debug('HTTP error')
except requests.exceptions.ConnectionError:
    print("Connection error")
    logging.debug('Connection error')
else:
    if r.status_code == 200:
        keyFamIdList = []
        keyFamNameList = []

        # use xmltodict and traverse nested ordered dictionaries
        keyfamilies_dict = xmltodict.parse(r.text)
        keyFamilies = keyfamilies_dict['message:Structure']['message:KeyFamilies']['KeyFamily']

        for keyFamily in keyFamilies:
            keyfam_id = keyFamily['@id']
            if (keyfam_id != 'NCM_LIVE' or keyfam_id != 'NCM_STAGING', True):
                keyFamIdList.append(keyfam_id)
                keyNames = keyFamily['Name']
                for keyName in keyNames: 
                    keyfam_lang = keyName['@xml:lang']
                    if keyfam_lang == 'en':
                        keyfam_text = keyName['#text']
                        keyFamNameList.append(keyfam_text)
            #print(keyfam_id, keyfam_text)
       
        keyFamDF = pd.DataFrame({'KeyFamilyId': keyFamIdList, 'KeyFamilyName': keyFamNameList})
        keyFamDF.set_index('KeyFamilyId', inplace=True)
        keyFamDF.to_csv(datafile)  

    else:
        print('HTTP Failed with code', r.status_code)
        logging.debug('HTTP Failed with code %d', r.status_code)
        
     
        # create a 2D list(needed?), and a data frame. Save data frame to csv file
        # keyFamTable = [keyFamIdList, keyFamNameList]
       

print("completed ...")
logging.debug("Log ended at %s", str(datetime.datetime.now()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-4baa417dd13d> in <module>
#      48                 keyNames = keyFamily['Name']
#      49                 for keyName in keyNames:
# ---> 50                     keyfam_lang = keyName['@xml:lang']
#      51                     if keyfam_lang == 'en':
#      52                         keyfam_text = keyName['#text']
#
# TypeError: string indices must be integers

# %%
keyfam_id
# Out:
# 'NCM_LIVE'

# %%
keyfam_lang
# Out:
# 'fr'

# %%
keyFamily['Name']
# Out:
# OrderedDict([('@xml:lang', 'en'), ('#text', 'NCM Staging cube')])

# %%
keyFamilies
# Out:
# [OrderedDict([('@id', 'QNA'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text', 'Quarterly National Accounts')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text', 'Comptes nationaux trimestriels')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'PAT_IND'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text', 'Patent indicators')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text', 'Brevets - Indicateurs')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'SNA_TABLE11'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               '11. Government expenditure by function (COFOG)')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               '11. Dépense des administrations publiques par fonction (COFOG)')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'EO78_MAIN'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Economic Outlook No 78 - December 2005 - Annual Projections for OECD Countries')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Perspectives économiques No 78 - décembre 2005 - Projections annuelles pour les pays OCDE')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'ANHRS'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Average annual hours actually worked per worker')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Heures moyennes annuelles ouvrées par travailleur')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'GOV_DEBT'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text', 'Central Government Debt')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               "Dette de l'administration centrale")])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'EO78_TRADE'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Economic Outlook No 78 - December 2005 - Annual Trade and Payments Projections')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Perspectives économiques No 78 - décembre 2005 - Perspectives annuelles des commerces et paiements')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'USLHRS_D'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Usual hours worked by weekly hour bands')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               "Durée du travail par tranche d'heures hebdomadaires")])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'SNA_TABLE10'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               '10. Taxes and social contributions receipts')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               '10. Impôts et cotisations sociales')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'EO77_MAIN'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Economic Outlook No 77 - June 2005 - Annual Projections for OECD Countries')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Perspectives économiques No 77 - juin 2005 - Perspectives annuelles pour les pays OCDE')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'USLHRS_I'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Incidence of employment by usual weekly hours worked')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               "Fréquence de l'emploi selon les durées hebdomadaires de travail")])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'EO77_TRADE'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Economic Outlook No 77 - June 2005 - Annual Trade and Payments Projections')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Perspectives économiques No 77 - juin 2005 - Perspectives annuelles des commerces et paiements')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'MEI_CLI'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text', 'Composite Leading Indicators (MEI)')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Indicateurs composites avancés (PIE)')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'JOBQ_I'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'OECD Inventory of Survey Questions on the Quality of the Working Environment')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               "Inventaire de l'OCDE des questions d'enquête sur la qualité de l'environnement de travail")])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'FTPTN_D'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'FTPT employment based on national definitions')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Emploi FTPT basée sur des définitions nationales')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'FTPTN_I'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Incidence of FTPT employment - national definitions')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               "Fréquence de l'emploi FTPT - définitions nationales")])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'MEI_REAL'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text', 'Production and Sales (MEI)')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text', 'Production et Ventes (PIE)')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'LMPEXP'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Public expenditure and participant stocks on LMP')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Dépenses publiques et nombre de participants PMT')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'MEI_BOP'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text', 'Archive - Balance of Payments BPM5')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Archive - Balance des paiements BPM5')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'ALFS_POP_VITAL'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text', 'Population and Vital Statistics')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Statistiques de population et statistiques vitales')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'ALFS_POP_LABOUR'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text', 'Population and Labour Force')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text', 'Population et population active')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'ALFS_EMP'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Employment by activities and status (ALFS)')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Emploi par activité et statut (ALFS)')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'FDI_FLOW_INDUSTRY'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text', 'FDI flows by industry')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text', 'IDE flux par industrie')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'EXP_PM2_5_FUA'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Exposure to PM2.5 in Functional Urban Areas')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Exposure to PM2.5 in Functional Urban Areas')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'PMR'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text', 'Product Market Regulation 2013.')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Réglementation du marché des produits 2013')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'DEC_I'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text', 'Decile ratios of gross earnings')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Ratios deciles des salaires bruts')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'HEALTH_STAT'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'), ('#text', 'Health Status')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text', 'État de Santé')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
# ...
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'EO95_INTERNET'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Economic Outlook No 95 - May 2014 - OECD Annual Projections')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               "Perspectives Economiques No 95 - Mai 2014 - Projections annuelles de l 'OCDE")])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'SNA_TABLE6A'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               '6A. Value added and its components by activity, ISIC rev4')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               '6A. Valeur ajoutée et ses composantes par activité, CITI rev4')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'PRICES_CPI'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Consumer price indices (CPIs) - Complete database')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Indice des prix à la consommation (IPCs) - Base de données complète')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'PDB_LV'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Level of GDP per capita and productivity')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Niveaux de PIB par tête et de productivité')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'PDB_GR'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Growth in GDP per capita, productivity and ULC')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Croissance du PIB par tête, de la productivité et des CUM')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'PDBI_I4'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Productivity and ULC by main economic activity (ISIC Rev.4)')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Productivité et CUM par principale activité économique (CITI Rev.4)')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'REVBAR'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text', 'Details of Tax Revenue - Barbados')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Recettes fiscales détaillées - Barbade')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  OrderedDict([('@id', 'FACTBOOK2014_PUB'),
#               ('@agencyID', 'OECD'),
#               ('Name',
#                [OrderedDict([('@xml:lang', 'en'),
#                              ('#text',
#                               'Factbook Country Statistical Profiles   -  2014 edition')]),
#                 OrderedDict([('@xml:lang', 'fr'),
#                              ('#text',
#                               'Panorama des statistiques  Profils statistiques par pays   -   édition 2014')])]),
#               ('Annotations',
#                OrderedDict([('common:Annotation',
#                              [OrderedDict([('common:AnnotationTitle',
#                                             'Copyright OECD - All rights reserved')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Terms and Conditions'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/termsandconditions/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Privacy Policy'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/privacy/')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'MyOECD'),
#                                            ('common:AnnotationURL',
#                                             'https://www.oecd.org/login')]),
#                               OrderedDict([('common:AnnotationTitle',
#                                             'Contact Us'),
#                                            ('common:AnnotationURL',
#                                             'http://www.oecd.org/contact/')])])]))]),
#  ...]
